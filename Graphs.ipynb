# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahmid-Amin/AI-Group_8/blob/main/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("./owid-covid-data.csv")
df

numerical_features = ['total_cases', 'total_deaths', 'new_cases', 'new_deaths', 'life_expectancy']

# Create histograms
for feature in numerical_features:
    plt.figure(figsize=(8, 4))
    plt.hist(df[feature], bins=20, edgecolor='k')
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
